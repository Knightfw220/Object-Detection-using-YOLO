# %% [markdown]
# This notebook introduces OpenCV step-by-step for beginners.

# %% [markdown]
# ## 1. Installation
# Run this once in your terminal:
# ```bash
# pip install opencv-python
# ```

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %% [markdown]
# ## 2. Read and Display an Image

# %%
import cv2

img = cv2.imread("image.png")
cv2.imshow("My Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Note: The last two lines are just to view the image in an image editor window. Until you open the editor the code will keep compiling.

# %% [markdown]
# ## 3. Convert to Grayscale

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 4. Resize Image

# %%
resized = cv2.resize(img, (400, 300))
cv2.imshow("Resized", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 5. Draw Shapes and Text

# %%
draw = img.copy()
cv2.rectangle(draw, (50,50), (200,200), (0,255,0), 2)
cv2.circle(draw, (300,200), 50, (255,0,0), 2)
cv2.putText(draw, "Hello OpenCV", (50,400),
            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

cv2.imshow("Drawing", draw)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 6. Edge Detection (Canny)

# %%
edges = cv2.Canny(gray, 50, 150)
cv2.imshow("Edges", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 7. Thresholding

# %%
_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
cv2.imshow("Threshold", thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 8. Webcam Capture (Press 'q' to quit)

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow("Webcam", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Real-time Edge Detection Camera

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)

    cv2.imshow("Edges", edges)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
